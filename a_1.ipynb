# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
numpy.random.seed(7)
# load pima indians dataset
dataset = numpy.loadtxt(r"pima-indians-diabetes.csv", delimiter=",")

# %%
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(X, Y, epochs=150, batch_size=10)
# evaluate the model
scores = model.evaluate(X, Y)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 3ms/step - loss: 1.7102 - accuracy: 0.5833
# Epoch 2/150
# 77/77 [==============================] - 0s 3ms/step - loss: 1.1837 - accuracy: 0.6029
# Epoch 3/150
# 77/77 [==============================] - 0s 3ms/step - loss: 1.0346 - accuracy: 0.6081
# Epoch 4/150
# 77/77 [==============================] - 0s 3ms/step - loss: 1.0413 - accuracy: 0.6003
# Epoch 5/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.9605 - accuracy: 0.6250
# Epoch 6/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.8868 - accuracy: 0.6328
# Epoch 7/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.8357 - accuracy: 0.6393
# Epoch 8/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7931 - accuracy: 0.6276
# Epoch 9/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7725 - accuracy: 0.6380
# Epoch 10/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7582 - accuracy: 0.6367
# Epoch 11/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6898 - accuracy: 0.6576
# Epoch 12/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7712 - accuracy: 0.6576
# Epoch 13/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7284 - accuracy: 0.6536
# Epoch 14/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6857 - accuracy: 0.6549
# Epoch 15/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6513 - accuracy: 0.6797
# Epoch 16/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6734 - accuracy: 0.6823
# Epoch 17/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6335 - accuracy: 0.6784
# Epoch 18/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6566 - accuracy: 0.6784
# Epoch 19/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6523 - accuracy: 0.6940
# Epoch 20/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7210 - accuracy: 0.6732
# Epoch 21/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6803 - accuracy: 0.6836
# Epoch 22/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6784
# Epoch 23/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6527 - accuracy: 0.6797
# Epoch 24/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6310 - accuracy: 0.6836
# Epoch 25/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5940 - accuracy: 0.6940
# Epoch 26/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5939 - accuracy: 0.6953
# Epoch 27/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5895 - accuracy: 0.7083
# Epoch 28/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5746 - accuracy: 0.7318
# Epoch 29/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6201 - accuracy: 0.6901
# Epoch 30/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5873 - accuracy: 0.7044
# Epoch 31/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5925 - accuracy: 0.6927
# Epoch 32/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6274 - accuracy: 0.6888
# Epoch 33/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6414 - accuracy: 0.6901
# Epoch 34/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6212 - accuracy: 0.6875
# Epoch 35/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5716 - accuracy: 0.7266
# Epoch 36/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6105 - accuracy: 0.7031
# Epoch 37/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5748 - accuracy: 0.7070
# Epoch 38/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5969 - accuracy: 0.7083
# Epoch 39/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5644 - accuracy: 0.7201
# Epoch 40/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.7122
# Epoch 41/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5910 - accuracy: 0.6901
# Epoch 42/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5622 - accuracy: 0.7240
# Epoch 43/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5651 - accuracy: 0.7148
# Epoch 44/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5857 - accuracy: 0.7122
# Epoch 45/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5685 - accuracy: 0.7240
# Epoch 46/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5627 - accuracy: 0.7174
# Epoch 47/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.7305
# Epoch 48/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5549 - accuracy: 0.7188
# Epoch 49/150
# 77/77 [==============================] - 0s 4ms/step - loss: 0.6159 - accuracy: 0.7122
# Epoch 50/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5578 - accuracy: 0.7240
# Epoch 51/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.7148
# Epoch 52/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.7474
# Epoch 53/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5298 - accuracy: 0.7370
# Epoch 54/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5788 - accuracy: 0.7174
# Epoch 55/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5730 - accuracy: 0.7122
# Epoch 56/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5272 - accuracy: 0.7318
# Epoch 57/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5591 - accuracy: 0.7253
# Epoch 58/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5668 - accuracy: 0.7357
# Epoch 59/150
# 77/77 [==============================] - 0s 4ms/step - loss: 0.5277 - accuracy: 0.7435
# Epoch 60/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5770 - accuracy: 0.7188
# Epoch 61/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5477 - accuracy: 0.7292
# Epoch 62/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5205 - accuracy: 0.7357
# Epoch 63/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5365 - accuracy: 0.7122
# Epoch 64/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6066 - accuracy: 0.7083
# Epoch 65/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5399 - accuracy: 0.7448
# Epoch 66/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5546 - accuracy: 0.7305
# Epoch 67/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5387 - accuracy: 0.7448
# Epoch 68/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5531 - accuracy: 0.7409
# Epoch 69/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.7409
# Epoch 70/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5286 - accuracy: 0.7487
# Epoch 71/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5402 - accuracy: 0.7565
# Epoch 72/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7214
# Epoch 73/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5504 - accuracy: 0.7357
# Epoch 74/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5323 - accuracy: 0.7279
# Epoch 75/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5361 - accuracy: 0.7279
# Epoch 76/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5382 - accuracy: 0.7409
# Epoch 77/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5326 - accuracy: 0.7357
# Epoch 78/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5304 - accuracy: 0.7513
# Epoch 79/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5238 - accuracy: 0.7448
# Epoch 80/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.7370
# Epoch 81/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.7383
# Epoch 82/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5773 - accuracy: 0.7201
# Epoch 83/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5324 - accuracy: 0.7422
# Epoch 84/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.7500
# Epoch 85/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5341 - accuracy: 0.7448
# Epoch 86/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5129 - accuracy: 0.7461
# Epoch 87/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5125 - accuracy: 0.7461
# Epoch 88/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5390 - accuracy: 0.7370
# Epoch 89/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5224 - accuracy: 0.7513
# Epoch 90/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5529 - accuracy: 0.7318
# Epoch 91/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.7318
# Epoch 92/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5171 - accuracy: 0.7396
# Epoch 93/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5134 - accuracy: 0.7604
# Epoch 94/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.7526
# Epoch 95/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5512 - accuracy: 0.7357
# Epoch 96/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.7422
# Epoch 97/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5445 - accuracy: 0.7331
# Epoch 98/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5528 - accuracy: 0.7253
# Epoch 99/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5001 - accuracy: 0.7591
# Epoch 100/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5119 - accuracy: 0.7604
# Epoch 101/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5158 - accuracy: 0.7513
# Epoch 102/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.7526
# Epoch 103/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.7539
# Epoch 104/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5077 - accuracy: 0.7474
# Epoch 105/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.7552
# Epoch 106/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5364 - accuracy: 0.7344
# Epoch 107/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5260 - accuracy: 0.7617
# Epoch 108/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5122 - accuracy: 0.7487
# Epoch 109/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5085 - accuracy: 0.7539
# Epoch 110/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5169 - accuracy: 0.7370
# Epoch 111/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5226 - accuracy: 0.7513
# Epoch 112/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5167 - accuracy: 0.7461
# Epoch 113/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5042 - accuracy: 0.7526
# Epoch 114/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5081 - accuracy: 0.7526
# Epoch 115/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.7526
# Epoch 116/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5282 - accuracy: 0.7474
# Epoch 117/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5210 - accuracy: 0.7318
# Epoch 118/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4916 - accuracy: 0.7656
# Epoch 119/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5123 - accuracy: 0.7565
# Epoch 120/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5025 - accuracy: 0.7552
# Epoch 121/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5186 - accuracy: 0.7591
# Epoch 122/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5164 - accuracy: 0.7487
# Epoch 123/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5256 - accuracy: 0.7448
# Epoch 124/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5159 - accuracy: 0.7565
# Epoch 125/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4996 - accuracy: 0.7617
# Epoch 126/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5108 - accuracy: 0.7396
# Epoch 127/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5186 - accuracy: 0.7604
# Epoch 128/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.7292
# Epoch 129/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5110 - accuracy: 0.7565
# Epoch 130/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.7682
# Epoch 131/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5053 - accuracy: 0.7565
# Epoch 132/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4900 - accuracy: 0.7786
# Epoch 133/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5068 - accuracy: 0.7656
# Epoch 134/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4894 - accuracy: 0.7630
# Epoch 135/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4907 - accuracy: 0.7565
# Epoch 136/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5577 - accuracy: 0.7240
# Epoch 137/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5447 - accuracy: 0.7318
# Epoch 138/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5029 - accuracy: 0.7591
# Epoch 139/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5057 - accuracy: 0.7448
# Epoch 140/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5443 - accuracy: 0.7331
# Epoch 141/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5259 - accuracy: 0.7513
# Epoch 142/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4917 - accuracy: 0.7852
# Epoch 143/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4875 - accuracy: 0.7682
# Epoch 144/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4905 - accuracy: 0.7760
# Epoch 145/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5024 - accuracy: 0.7682
# Epoch 146/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4875 - accuracy: 0.7617
# Epoch 147/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5093 - accuracy: 0.7513
# Epoch 148/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.7578
# Epoch 149/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5208 - accuracy: 0.7604
# Epoch 150/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5127 - accuracy: 0.7643
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6353 - accuracy: 0.6836

# %%
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 68.36%

# %%
from ann_visualizer.visualize import ann_viz;

ann_viz(model,  filename="network.gv",title="My graph")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80     else:
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#      82 except OSError as e:
#
# File ~\anaconda3\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#
# File ~\anaconda3\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#
# File ~\anaconda3\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 from ann_visualizer.visualize import ann_viz;
# ----> 3 ann_viz(model,  filename="network.gv",title="My graph")
#
# File ~\anaconda3\lib\site-packages\ann_visualizer\visualize.py:206, in ann_viz(model, view, filename, title)
#     204 g.edge_attr.update(arrowhead="none", color="#707070");
#     205 if view == True:
# --> 206     g.view()
#
# File ~\anaconda3\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\graphviz\rendering.py:185, in Render.view(self, filename, directory, cleanup, quiet, quiet_view)
#     150 @_tools.deprecate_positional_args(supported_number=2)
#     151 def view(self,
#     152          filename: typing.Union[os.PathLike, str, None] = None,
#    (...)
#     155          quiet: bool = False,
#     156          quiet_view: bool = False) -> str:
#     157     """Save the source to file, open the rendered result in a viewer.
#     158
#     159     Convenience short-cut for running ``.render(view=True)``.
#    (...)
#     183         and no way to retrieve the application's exit status.
#     184     """
# --> 185     return self.render(filename=filename, directory=directory, view=True,
#     186                        cleanup=cleanup, quiet=quiet, quiet_view=quiet_view)
#
# File ~\anaconda3\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\graphviz\rendering.py:122, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
# --> 122 rendered = self._render(*args, **kwargs)
#     124 if cleanup:
#     125     log.debug('delete %r', filepath)
#
# File ~\anaconda3\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\graphviz\backend\rendering.py:324, in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     320     raise exceptions.FileExistsError(f'output file exists: {os.fspath(outfile)!r}')
#     322 cmd += args
# --> 324 execute.run_check(cmd,
#     325                   cwd=filepath.parent if filepath.parent.parts else None,
#     326                   quiet=quiet,
#     327                   capture_output=True)
#     329 return os.fspath(outfile)
#
# File ~\anaconda3\lib\site-packages\graphviz\backend\execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\poona\anaconda3\lib\site-packages (from visualkeras) (1.21.5)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.15-cp39-cp39-win_amd64.whl (43 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\poona\anaconda3\lib\site-packages (from visualkeras) (9.0.1)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.15 visualkeras-0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import visualkeras
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=107x27 at 0x1E3C33B0190>
